# %% [markdown]
# <a href="https://colab.research.google.com/github/kubra-bulut/Data-Mining/blob/main/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # Veri işleme

# Visiualization tools
import matplotlib.pyplot as plt
import seaborn as sns

#Machine Learning tools
#Önişleme
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler

#Model Seçimi
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

#Makine Öğrenmesi Modelleri
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
#Metrikler
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report


#Sistem Kütüphaneleri
import os

# %%
dataset=pd.read_csv('diabetic_data.csv')

# %%
dataset.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
dataset.dropna(subset=['weight'], inplace=True)
print(dataset)
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
dataset.dropna(subset = ['weight'], inplace =True )

# %%
dataset.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
clear_dataset = dataset[dataset['weight'] != "?"]
clear_dataset
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 1102         8042082     94466574        Caucasian    Male  [50-60)
# 1108         8057670     96198543                ?  Female  [80-90)
# 1132         8235036     79874631        Caucasian  Female  [60-70)
# 1136         8274126     90421380        Caucasian  Female  [40-50)
# 1190         8421486     55628172        Caucasian  Female  [70-80)
# ...              ...          ...              ...     ...      ...
# 101456     439606454    113392368  AfricanAmerican    Male  [60-70)
# 101516     440252540     97508430        Caucasian    Male  [60-70)
# 101640     442077494     62420742        Caucasian  Female  [70-80)
# 101667     442577684     78208677        Caucasian    Male  [70-80)
# 101723     443695760     98476776        Caucasian    Male  [60-70)
#
#            weight  admission_type_id  discharge_disposition_id  \
# 1102     [75-100)                  6                         1
# ...

# %%
clear_dataset=clear_dataset.drop(columns=['encounter_id', 'patient_nbr', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id','payer_code', 'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum', 'repaglinide', 'nateglinide', 'chlorpropamide', 'tolbutamide', 'miglitol', 'troglitazone', 'tolazamide', 'examide', 'citoglipton', 'glyburide-metformin', 'glipizide-metformin', 'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 'readmitted'])

# %%
clear_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3197 entries, 1102 to 101723
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   race                3197 non-null   object
#  1   gender              3197 non-null   object
#  2   age                 3197 non-null   object
#  3   weight              3197 non-null   object
#  4   time_in_hospital    3197 non-null   int64
#  5   num_lab_procedures  3197 non-null   int64
#  6   num_procedures      3197 non-null   int64
#  7   num_medications     3197 non-null   int64
#  8   number_outpatient   3197 non-null   int64
#  9   number_emergency    3197 non-null   int64
#  10  number_inpatient    3197 non-null   int64
#  11  number_diagnoses    3197 non-null   int64
#  12  A1Cresult           346 non-null    object
#  13  metformin           3197 non-null   object
#  14  glimepiride         3197 non-null   object
# ...

# %%
from sklearn.model_selection import train_test_split

# Bağımsız değişkenler (X) ve hedef değişken (y) ayırma
X = clear_dataset.drop('diabetesMed', axis=1)
y = clear_dataset['diabetesMed']

# Veri setini eğitim ve test kümelerine bölmek
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
pip install category_encoders

# %%
# display categorical variables

categorical = [col for col in X_train.columns if X_train[col].dtypes == 'O']

categorical
# Out:
# ['race',
#  'gender',
#  'age',
#  'weight',
#  'A1Cresult',
#  'metformin',
#  'glimepiride',
#  'acetohexamide',
#  'glipizide',
#  'glyburide',
#  'pioglitazone',
#  'rosiglitazone',
#  'acarbose',
#  'insulin',
#  'change']

# %%
X_train.head()
# Out:
#             race  gender       age    weight  time_in_hospital  \
# 71889      Asian  Female   [70-80)   [50-75)                 4
# 79832  Caucasian  Female  [90-100)   [50-75)                 7
# 37747  Caucasian    Male   [80-90)   [50-75)                 7
# 42243  Caucasian  Female   [80-90)  [75-100)                 5
# 11360  Caucasian  Female   [60-70)   [50-75)                 4
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 71889                  39               2               16                  0
# 79832                  48               0               13                  0
# 37747                  29               0               10                  0
# 42243                  52               0               15                  0
# 11360                  13               3               20                  2
#
#        number_emergency  ...  metformin  glimepiride acetohexamide glipizide  \
# ...

# %%
categorical = [col for col in X_train.columns if X_train[col].dtypes == 'O']

categorical
# Out:
# ['age', 'weight']

# %%
X_train.head()
# Out:
#             race  gender  age_1  age_2  age_3  age_4  age_5  age_6  age_7  \
# 31172      Asian  Female      1      0      0      0      0      0      0
# 9628   Caucasian  Female      0      1      0      0      0      0      0
# 29835  Caucasian  Female      1      0      0      0      0      0      0
# 50843  Caucasian  Female      0      0      1      0      0      0      0
# 7609   Caucasian    Male      0      1      0      0      0      0      0
#
#        age_8  ...  metformin  glimepiride  acetohexamide  glipizide  \
# 31172      0  ...         No           No             No         No
# 9628       0  ...         No           No             No         No
# 29835      0  ...         No           No             No         No
# 50843      0  ...         Up           No             No         No
# 7609       0  ...         No           No             No     Steady
#
#        glyburide  pioglitazone  rosiglitazone  acarbose  insulin  change
# ...

# %%
import category_encoders as ce

# %%
# encode remaining variables with one-hot encoding

encoder = ce.OneHotEncoder(cols=['race', 'gender'])

X_train = encoder.fit_transform(X_train)

X_test = encoder.transform(X_test)

# %%
from sklearn.metrics import f1_score
gaussian = GaussianNB()
gaussian.fit(X_train, y_train)
Y_pred = gaussian.predict(X_test)
accuracy_nb=round(accuracy_score(y_test,Y_pred)* 100, 2)
acc_gaussian = round(gaussian.score(X_train, y_train) * 100, 2)

cm = confusion_matrix(y_test, Y_pred)
accuracy = accuracy_score(y_test,Y_pred)
precision =precision_score(y_test, Y_pred,average='micro')
recall =  recall_score(y_test, Y_pred,average='micro')
f1 = f1_score(y_test,Y_pred,average='micro')
print('Confusion matrix for Naive Bayes\n',cm)
print('accuracy_Naive Bayes: %.3f' %accuracy)
print('precision_Naive Bayes: %.3f' %precision)
print('recall_Naive Bayes: %.3f' %recall)
print('f1-score_Naive Bayes : %.3f' %f1)
# Out:
# Confusion matrix for Naive Bayes
#  [[286   0]
#  [ 12 662]]
# accuracy_Naive Bayes: 0.988
# precision_Naive Bayes: 0.988
# recall_Naive Bayes: 0.988
# f1-score_Naive Bayes : 0.988

# %%
from sklearn.naive_bayes import GaussianNB


# instantiate the model
gnb = GaussianNB()


# fit the model
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

y_pred
# Out:
# array(['No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes',
#        'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No',
#        'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes'],
#       dtype='<U3')

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score: 1.0000

# %%
y_pred_train = gnb.predict(X_train)

y_pred_train
# Out:
# array(['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No',
#        'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes',
#        'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'No', 'Yes'], dtype='<U3')

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))
# Out:
# Training-set accuracy score: 1.0000

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print('Confusion matrix\n\n', cm)

print('\nTrue Positives(TP) = ', cm[0,0])

print('\nTrue Negatives(TN) = ', cm[1,1])

print('\nFalse Positives(FP) = ', cm[0,1])

print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[ 9  0]
#  [ 0 20]]
#
# True Positives(TP) =  9
#
# True Negatives(TN) =  20
#
# False Positives(FP) =  0
#
# False Negatives(FN) =  0

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       1.00      1.00      1.00         9
#          Yes       1.00      1.00      1.00        20
#
#     accuracy                           1.00        29
#    macro avg       1.00      1.00      1.00        29
# weighted avg       1.00      1.00      1.00        29

# %%
# encode remaining variables with one-hot encoding

encoder = ce.OneHotEncoder(cols=['A1Cresult',
 'metformin',
 'glimepiride',
 'acetohexamide',
 'glipizide',
 'glyburide',
 'pioglitazone',
 'rosiglitazone',
 'acarbose',
 'insulin',
 'change'])

X_train = encoder.fit_transform(X_train)

X_test = encoder.transform(X_test)

# %%
y_train.head()
# Out:
# 31172     No
# 9628     Yes
# 29835    Yes
# 50843    Yes
# 7609     Yes
# Name: diabetesMed, dtype: object

# %%
categorical = [col for col in X_train.columns if X_train[col].dtypes == 'O']

categorical
# Out:
# []

# %%
# import Random Forest classifier

from sklearn.ensemble import RandomForestClassifier



# instantiate the classifier

rfc = RandomForestClassifier(random_state=0)



# fit the model

rfc.fit(X_train, y_train)



# Predict the Test set results

y_pred = rfc.predict(X_test)



# Check accuracy score

from sklearn.metrics import accuracy_score

print('Model accuracy score with 10 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 10 decision-trees : 0.9927

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.98      1.00      0.99       306
#          Yes       1.00      0.99      0.99       654
#
#     accuracy                           0.99       960
#    macro avg       0.99      0.99      0.99       960
# weighted avg       0.99      0.99      0.99       960
